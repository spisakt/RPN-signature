# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nilearn.connectome import vec_to_sym_matrix, sym_matrix_to_vec
from nilearn.connectome import ConnectivityMeasure
from matplotlib import cm
from matplotlib.colors import Normalize

import sys
sys.path.append('../')
from PAINTeR import plot # in-house lib used for the RPN-signature

# %% [markdown]
# # Load behavioral data

# %%
# load data
df_bochum = pd.read_csv("../res/bochum_sample_excl.csv")
df_essen = pd.read_csv("../res/essen_sample_excl.csv")
df_szeged = pd.read_csv("../res/szeged_sample_excl.csv")
df_bochum['study'] = 'bochum'
df_essen['study'] = 'essen'
df_szeged['study'] = 'szeged'
df = pd.concat((df_bochum, df_essen, df_szeged), sort=False)
df = df.reset_index()

# %% [markdown]
# # Compute connectivity

# %%
timeseries = []
perc_scrubbed = []
for i, f in enumerate(df['ts_file']):
    f = '..' + f.split('/..')[1]
    f_scrub = f.split('.tsv')[0] + '-scrubbed.tsv'

    ts = pd.read_csv(f_scrub).iloc[:, 1:]  # here we can omit global signal...

    fd_file = df["fd_file"].values[i]
    fd_file = '..' + fd_file.split('/..')[1]
    fd = pd.read_csv(fd_file).values.ravel().tolist()
    fd = [0] + fd

    perc_scrubbed.append(100 - 100 * len(ts.shape) / len(fd))
    timeseries.append(ts.values)

# double check visually
sub_idx = 10  # modify this for a different subject
# modify below for different regions (see the next cell for region names)
pd.DataFrame(timeseries[sub_idx], columns=ts.columns.values).loc[:, ['AINS_pd', 'AINS_v', 'PINS_v']].plot()
## Load region and module names for the MIST122 atlas
labels = ts.columns.values
l = pd.read_csv('../data/atlas_relabeled.tsv', sep="\t")
modules = np.insert(l['modules'].values, 0, "GlobSig")
print('Region names:\n', labels)
## Calculate functional connectivity as partial correlation
correlation_measure = ConnectivityMeasure(kind='partial correlation', vectorize=False)
X = correlation_measure.fit_transform(timeseries)  # these are the features
joblib.dump(X, "../res/multi-center/all_features.joblib")

# double-check the mean matrix visually
mat = correlation_measure.mean_
#mat=mat[1:, 1:] #fisrt row and column is global signal
mat[range(mat.shape[0]), range(mat.shape[0])] = 0  # zero diag
plot.plot_matrix(mat, labels, modules)
# Out:
# Region names:
#  ['GlobSig' 'CER6_p' 'CER7ab' 'R_CERCR2_p' 'CER9_v' 'CER6_a' 'L_CERCR2_a'
#  'CER9_d' 'CER9_m' 'CER7b_m' 'L_CERCR2_p' 'CER7b_l' 'N' 'CERCR1' 'CER6_d'
#  'CER5' 'R_CERCR2_a' 'POsul_d' 'POsul_v' 'VMPFcor_p' 'R_MTgyr_a'
#  'L_ANGgyr' 'L_MTgyr_p' 'L_MTgyr_a' 'DMPFC_ar' 'L_SFsul_a' 'DMPFcor_ac'
#  'PCcor' 'POsul' 'L_IPlob' 'PGACcor' 'VMPFcor_a' 'PRC_d' 'SFgyr_ad'
#  'L_IPlob.1' 'R_ANGgyr' 'PRC_v' 'R_MTgyr_p' 'PRC_d.1' 'R_MFgyr_a'
#  'L_DVIS_v' 'SPlob' 'R_VLPFcor' 'FUSgyr_vl' 'R_IFsul' 'FP' 'R_DVIS_v'
#  'L_FP_l' 'SPlob.1' 'L_MFgyr_pc' 'L_VLPFcor' 'OCCTgyr_l' 'ACcor_d'
#  'L_MFgyr_pr' 'R_MFgyr_p' 'R_IPsul' 'L_IFsul' 'DVIS_s' 'FUSgyr_dl'
#  'R_SFsul' 'R_IPlob' 'R_FP_l' 'R_PORB' 'DMPFcor_p' 'L_IPsul' 'L_MFgyr_a'
#  'DVIS_vl' 'CAUDNH_NACC' 'COLsul' 'LORBgyr' 'ITgyr' 'STgyr_a' 'MORBgyr'
#  'PINS_v' 'TP' 'HIPP' 'AMY' 'PIsul' 'CERVM' 'L_MOTnet_dl' 'MOTnet_am'
#  'R_MOTnet_dl' 'MOTnet_m' 'MOTnet_ml' 'MOTnet_vl' 'MOTnet_l' 'l_PCsul'
#  'CNGsul_p' 'PUT_p' 'AINS_pd' 'CAUDN_d' 'AINS_v' 'FEF' 'PCsul_d' 'IMsul'
#  'STgyr_p' 'CAUDN_v' 'PUT_a' 'HSgyr' 'PSMcor_p' 'PSMcor_a' 'SMgyr'
#  'THAL_d' 'THAL_v' 'R_PCsul' 'PINS_d' 'STgyr_m' 'PCcor.1' 'AINS_ad'
#  'CAUDN' 'PVISnet_l' 'MDVISnet_p' 'MDVISnet_a' 'LVISnet_vp' 'MVISnet_p'
#  'MVISnet_av' 'LVISnet_p' 'PVISnet_dm' 'PVISnet_vm' 'MVISnet_ad'
#  'VVISnet_l' 'LVISnet_DP' 'VVISnet_m']

# %%
X.shape
# Out:
# (91, 123, 123)

# %% [markdown]
# # Load participant-level connectivity data

# %%
mc_model = pd.read_csv('../res/multi-center/finalized_model_connections.csv')
#mc_model = mc_model.sort_values(by=['abs_multi-center'], ascending=False).head(40)
mc_model = mc_model[mc_model['abs_multi-center']>0.02]
sns.histplot(mc_model['abs_multi-center'])
mc_model
# Out:
#     Unnamed: 0  idx_A        reg_A                     mod_A  idx_B  \
# 0            0      0      GlobSig                 2_MEAN_GM     19
# 2            2      1       CER6_p                     1_CER     99
# 3            3      2       CER7ab                     1_CER     67
# 4            4      3   R_CERCR2_p                     1_CER     16
# 5            5      3   R_CERCR2_p                     1_CER     71
# 8            8      6   L_CERCR2_a                     1_CER     20
# 14          14      9      CER7b_m                     1_CER    107
# 16          16     11      CER7b_l                     1_CER     62
# 21          21     14       CER6_d                     1_CER     51
# 22          22     14       CER6_d                     1_CER     82
# 25          25     16   R_CERCR2_a                     1_CER     85
# 26          26     18      POsul_v                   7_DMnet     62
# 28          28     20    R_MTgyr_a                   7_DMnet     33
# 29          29     20    R_MTgyr_a                   7_DMnet     96
# 30          30     21     L_ANGgyr                   7_DMnet     60
# 31          31     21     L_ANGgyr                   7_DMnet    113
# 32          32     24     DMPFC_ar                   7_DMnet     37
# 34          34     26   DMPFcor_ac                   7_DMnet     90
# 36          36     27        PCcor                   7_DMnet    119
# 39          39     33     SFgyr_ad                   7_DMnet     95
# 42          42     36        PRC_v                   7_DMnet     66
# 43          43     37    R_MTgyr_p                   7_DMnet     78
# 46          46     39    R_MFgyr_a             5_FPnet_VISDN     88
# 47          47     40     L_DVIS_v             5_FPnet_VISDN    112
# 52          52     46     R_DVIS_v             5_FPnet_VISDN     76
# 53          53     50    L_VLPFcor             5_FPnet_VISDN    101
# 57          57     57       DVIS_s             5_FPnet_VISDN    102
# 58          58     58    FUSgyr_dl             5_FPnet_VISDN     76
# 60          60     60      R_IPlob             5_FPnet_VISDN     94
# 61          61     60      R_IPlob             5_FPnet_VISDN     95
# 63          63     65    L_MFgyr_a             5_FPnet_VISDN     69
# 65          65     67  CAUDNH_NACC                  4_LIMnet     84
# 66          66     68       COLsul                  4_LIMnet     84
# 69          69     74           TP                  4_LIMnet    109
# 76          76     82     MOTnet_m                  6_MOTnet    116
# 80          80     91       AINS_v  3_VATTnet_SALnet_BG_THAL    119
# 82          82     95      STgyr_p  3_VATTnet_SALnet_BG_THAL    121
# 83          83    102       THAL_d  3_VATTnet_SALnet_BG_THAL    107
# 84          84    103       THAL_v  3_VATTnet_SALnet_BG_THAL    105
#
#           reg_B                     mod_B  multi-center  abs_multi-center  \
# 0     VMPFcor_p                   7_DMnet      0.072555          0.072555
# 2      PSMcor_p  3_VATTnet_SALnet_BG_THAL     -0.082088          0.082088
# 3   CAUDNH_NACC                  4_LIMnet      0.034224          0.034224
# 4    R_CERCR2_a                     1_CER      0.022155          0.022155
# 5       STgyr_a                  4_LIMnet     -0.051295          0.051295
# 8     R_MTgyr_a                   7_DMnet     -0.026498          0.026498
# 14      PCcor.1  3_VATTnet_SALnet_BG_THAL      0.081284          0.081284
# 16       R_PORB             5_FPnet_VISDN     -0.027177          0.027177
# 21    OCCTgyr_l             5_FPnet_VISDN     -0.046375          0.046375
# 22     MOTnet_m                  6_MOTnet     -0.090278          0.090278
# 25     MOTnet_l                  6_MOTnet      0.082394          0.082394
# 26       R_PORB             5_FPnet_VISDN      0.140461          0.140461
# 28     SFgyr_ad                   7_DMnet     -0.067593          0.067593
# 29      CAUDN_v  3_VATTnet_SALnet_BG_THAL      0.049010          0.049010
# 30      R_IPlob             5_FPnet_VISDN     -0.061289          0.061289
# 31   LVISnet_vp                  8_VISnet     -0.093174          0.093174
# 32    R_MTgyr_p                   7_DMnet     -0.112056          0.112056
# 34      CAUDN_d  3_VATTnet_SALnet_BG_THAL      0.138918          0.138918
# 36   MVISnet_ad                  8_VISnet     -0.020735          0.020735
# 39      STgyr_p  3_VATTnet_SALnet_BG_THAL      0.059889          0.059889
# 42      DVIS_vl             5_FPnet_VISDN     -0.024423          0.024423
# 43        CERVM                  4_LIMnet     -0.040727          0.040727
# 46        PUT_p  3_VATTnet_SALnet_BG_THAL     -0.098362          0.098362
# 47   MDVISnet_a                  8_VISnet     -0.041732          0.041732
# 52          AMY                  4_LIMnet      0.056862          0.056862
# 53        SMgyr  3_VATTnet_SALnet_BG_THAL     -0.051700          0.051700
# 57       THAL_d  3_VATTnet_SALnet_BG_THAL     -0.027343          0.027343
# 58          AMY                  4_LIMnet     -0.085955          0.085955
# 60        IMsul  3_VATTnet_SALnet_BG_THAL      0.047546          0.047546
# 61      STgyr_p  3_VATTnet_SALnet_BG_THAL     -0.052489          0.052489
# 63      LORBgyr                  4_LIMnet      0.163320          0.163320
# 65    MOTnet_vl                  6_MOTnet      0.080333          0.080333
# 66    MOTnet_vl                  6_MOTnet     -0.043420          0.043420
# 69        CAUDN  3_VATTnet_SALnet_BG_THAL     -0.020965          0.020965
# 76    LVISnet_p                  8_VISnet      0.071727          0.071727
# 80   MVISnet_ad                  8_VISnet     -0.083777          0.083777
# 82   LVISnet_DP                  8_VISnet      0.032784          0.032784
# 83      PCcor.1  3_VATTnet_SALnet_BG_THAL      0.030910          0.030910
# 84       PINS_d  3_VATTnet_SALnet_BG_THAL      0.097145          0.097145
#
#                connectivity
# 0       GlobSig - VMPFcor_p
# 2         CER6_p - PSMcor_p
# 3      CER7ab - CAUDNH_NACC
# 4   R_CERCR2_p - R_CERCR2_a
# 5      R_CERCR2_p - STgyr_a
# 8    L_CERCR2_a - R_MTgyr_a
# 14        CER7b_m - PCcor.1
# 16         CER7b_l - R_PORB
# 21       CER6_d - OCCTgyr_l
# 22        CER6_d - MOTnet_m
# 25    R_CERCR2_a - MOTnet_l
# 26         POsul_v - R_PORB
# 28     R_MTgyr_a - SFgyr_ad
# 29      R_MTgyr_a - CAUDN_v
# 30       L_ANGgyr - R_IPlob
# 31    L_ANGgyr - LVISnet_vp
# 32     DMPFC_ar - R_MTgyr_p
# 34     DMPFcor_ac - CAUDN_d
# 36       PCcor - MVISnet_ad
# 39       SFgyr_ad - STgyr_p
# 42          PRC_v - DVIS_vl
# 43        R_MTgyr_p - CERVM
# 46        R_MFgyr_a - PUT_p
# 47    L_DVIS_v - MDVISnet_a
# 52           R_DVIS_v - AMY
# 53        L_VLPFcor - SMgyr
# 57          DVIS_s - THAL_d
# 58          FUSgyr_dl - AMY
# 60          R_IPlob - IMsul
# 61        R_IPlob - STgyr_p
# 63      L_MFgyr_a - LORBgyr
# 65  CAUDNH_NACC - MOTnet_vl
# 66       COLsul - MOTnet_vl
# 69               TP - CAUDN
# 76     MOTnet_m - LVISnet_p
# 80      AINS_v - MVISnet_ad
# 82     STgyr_p - LVISnet_DP
# 83         THAL_d - PCcor.1
# 84          THAL_v - PINS_d

# %%
conns_mc_model = np.zeros((X.shape[0], len(mc_model)))
for idx, (i_a, i_b) in enumerate(zip(mc_model.idx_A, mc_model.idx_B)):
    #conns_mc_model(i_a, i_b)
    conns_mc_model[:, idx] = X[:, i_a, i_b]
conns_mc_model = pd.DataFrame(conns_mc_model, columns=mc_model.connectivity)
conns_mc_model
# Out:
# connectivity  GlobSig - VMPFcor_p  CER6_p - PSMcor_p  CER7ab - CAUDNH_NACC  \
# 0                        0.021891           0.127759             -0.021352
# 1                        0.015723           0.094542              0.125166
# 2                        0.013114          -0.090155              0.052071
# 3                        0.020028          -0.031791              0.147238
# 4                        0.027947          -0.003799              0.133163
# ..                            ...                ...                   ...
# 86                       0.031210           0.011089              0.026238
# 87                       0.021306           0.037766              0.173000
# 88                       0.014579          -0.108385              0.099388
# 89                       0.019275          -0.146022              0.036162
# 90                       0.024264          -0.027375              0.007382
#
# connectivity  R_CERCR2_p - R_CERCR2_a  R_CERCR2_p - STgyr_a  \
# 0                            0.145841             -0.064799
# 1                            0.201690             -0.074666
# 2                            0.068738              0.030321
# 3                            0.190687              0.042861
# 4                            0.153021             -0.029537
# ..                                ...                   ...
# 86                           0.210191             -0.017681
# 87                           0.157848             -0.082971
# 88                           0.053617              0.046721
# 89                           0.247881              0.005831
# 90                           0.207617              0.043937
#
# connectivity  L_CERCR2_a - R_MTgyr_a  CER7b_m - PCcor.1  CER7b_l - R_PORB  \
# 0                          -0.048813          -0.042026          0.000000
# 1                          -0.122995           0.091628          0.000000
# 2                          -0.032115          -0.196758          0.124899
# 3                          -0.048255           0.030311          0.000386
# 4                          -0.038915           0.017608          0.087969
# ..                               ...                ...               ...
# 86                         -0.078204          -0.048726         -0.013898
# 87                          0.017431          -0.028058          0.009052
# 88                         -0.120663          -0.066575          0.071326
# 89                          0.169983           0.146273         -0.056621
# 90                         -0.035985          -0.125673         -0.087620
#
# connectivity  CER6_d - OCCTgyr_l  CER6_d - MOTnet_m  ...  R_IPlob - STgyr_p  \
# 0                      -0.079679          -0.100725  ...          -0.065551
# 1                      -0.016422           0.012459  ...          -0.005558
# 2                       0.121946          -0.059550  ...           0.044654
# 3                       0.081606           0.036209  ...          -0.003451
# 4                       0.030264          -0.045649  ...          -0.030480
# ..                           ...                ...  ...                ...
# 86                      0.014368          -0.004617  ...           0.010992
# 87                      0.032332           0.055295  ...          -0.047451
# 88                      0.013218           0.054301  ...           0.014420
# 89                      0.023395           0.030448  ...          -0.020894
# 90                      0.059502          -0.046890  ...           0.033707
#
# connectivity  L_MFgyr_a - LORBgyr  CAUDNH_NACC - MOTnet_vl  \
# 0                       -0.012065                 0.054709
# 1                        0.067681                 0.077508
# 2                       -0.003242                 0.011217
# 3                        0.033829                -0.082446
# 4                       -0.038245                -0.159668
# ..                            ...                      ...
# 86                       0.045305                 0.025894
# 87                       0.077870                -0.138718
# 88                      -0.199809                -0.006506
# 89                       0.014597                -0.046275
# 90                       0.044891                -0.117693
#
# connectivity  COLsul - MOTnet_vl  TP - CAUDN  MOTnet_m - LVISnet_p  \
# 0                      -0.096509    0.119536             -0.046985
# 1                       0.010236   -0.020578              0.023110
# 2                      -0.023302    0.027970             -0.017286
# 3                      -0.008410    0.189698              0.066444
# 4                      -0.042111    0.041197              0.021621
# ..                           ...         ...                   ...
# 86                      0.027661   -0.036706              0.020761
# 87                     -0.031196   -0.071744             -0.047688
# 88                      0.032511   -0.067470             -0.020835
# 89                     -0.092783   -0.076256             -0.016585
# 90                      0.028190    0.029527             -0.008781
#
# connectivity  AINS_v - MVISnet_ad  STgyr_p - LVISnet_DP  THAL_d - PCcor.1  \
# 0                        0.112617             -0.018719         -0.074869
# 1                        0.137049             -0.016450         -0.015471
# 2                        0.104354              0.069925          0.113806
# 3                       -0.022866              0.053899         -0.073163
# 4                       -0.010212             -0.039720         -0.019237
# ..                            ...                   ...               ...
# 86                       0.040750             -0.016146         -0.020249
# 87                       0.042326              0.023084          0.100832
# 88                      -0.049692              0.069901          0.094161
# 89                      -0.005255             -0.075313          0.036747
# 90                       0.012935             -0.031323         -0.031373
#
# connectivity  THAL_v - PINS_d
# 0                   -0.006091
# 1                    0.032730
# 2                   -0.111940
# 3                    0.060156
# 4                    0.064941
# ..                        ...
# 86                   0.095300
# 87                  -0.052292
# 88                  -0.025747
# 89                  -0.094788
# 90                   0.017895
#
# [91 rows x 39 columns]

# %%
#vars = df[['Male', 'Age', 'CDT_log_mean', 'WDT_log_mean', 'MDT_log_geom', 'CPT', 'HPT', 'MPT_log_geom', 't50', 'psq', 'pcs_catastrophizing', 'pcs_rumination', 'PSQI', 'anx_state', 'anx_trait', 'PSQ20', 'ads_k', 'Glx_mean', 'GABA_mean', 'meanFD', 'maxFD', 'medianFD', 'BP_MRI_sys', 'BP_MRI_dias', 'BP_QST_sys', 'BP_QST_dias' ]]
df2 = df.copy()
df2['nHPT'] = df.HPT * -1
df2['nMPT'] = df.MPT_log_geom * -1
df2['nt50'] = df.t50 * -1
df2['npsq'] = df.psq * -1
df2['nanx_state'] = df.anx_state * -1
df2['nanx_trait'] = df.anx_trait * -1

vars = df2[['CPT', 'nHPT', 'nMPT', 'nt50', 'npsq', 'nanx_state', 'nanx_trait', 'pcs_catastrophizing', 'pcs_rumination', 'PSQI', 'PSQ20', 'ads_k', 'Glx_mean', 'GABA_mean' ]]

vars.corrwith(df.mean_QST_pain_sensitivity)
# Out:
# CPT                    0.714782
# nHPT                   0.769679
# nMPT                   0.634185
# nt50                   0.534950
# npsq                   0.190144
# nanx_state             0.202458
# nanx_trait             0.204718
# pcs_catastrophizing    0.134912
# pcs_rumination         0.215321
# PSQI                   0.296726
# PSQ20                  0.308412
# ads_k                  0.081807
# Glx_mean               0.311628
# GABA_mean              0.212076
# dtype: float64

# %%
corrmtx = np.zeros((vars.shape[1], conns_mc_model.shape[1]))

for i in range(vars.shape[1]):
    for j in range(conns_mc_model.shape[1]):
        mask = ~np.isnan(vars.values[:,i]) & ~np.isnan(conns_mc_model.values[:,j])
        corrmtx[i, j] = np.corrcoef(vars.values[mask,i], conns_mc_model.values[mask,j])[0,1]
corrmtx = pd.DataFrame(corrmtx, columns=conns_mc_model.columns, index=vars.columns)
corrmtx
# Out:
# connectivity         GlobSig - VMPFcor_p  CER6_p - PSMcor_p  \
# CPT                             0.218888          -0.231473
# nHPT                            0.161564          -0.254461
# nMPT                            0.301945          -0.201422
# nt50                            0.009989          -0.319194
# npsq                            0.361906          -0.009865
# nanx_state                      0.394896          -0.026690
# nanx_trait                      0.385377          -0.042216
# pcs_catastrophizing             0.005730          -0.111155
# pcs_rumination                  0.159344          -0.025577
# PSQI                           -0.080914          -0.190889
# PSQ20                           0.082060          -0.143464
# ads_k                           0.079481          -0.087482
# Glx_mean                        0.066142          -0.188863
# GABA_mean                       0.225794          -0.059636
#
# connectivity         CER7ab - CAUDNH_NACC  R_CERCR2_p - R_CERCR2_a  \
# CPT                              0.310017                 0.181493
# nHPT                             0.347498                 0.252683
# nMPT                             0.027588                 0.164708
# nt50                             0.069174                 0.084996
# npsq                             0.077909                 0.375797
# nanx_state                       0.001207                 0.431048
# nanx_trait                       0.007472                 0.413689
# pcs_catastrophizing             -0.052501                 0.040152
# pcs_rumination                  -0.138164                 0.101819
# PSQI                            -0.033573                 0.221576
# PSQ20                           -0.014080                 0.320610
# ads_k                            0.014304                 0.210167
# Glx_mean                         0.170221                 0.078672
# GABA_mean                        0.004655                -0.091192
#
# connectivity         R_CERCR2_p - STgyr_a  L_CERCR2_a - R_MTgyr_a  \
# CPT                             -0.136003               -0.088551
# nHPT                            -0.232522               -0.113355
# nMPT                            -0.118144               -0.064367
# nt50                             0.015976               -0.007896
# npsq                             0.105488                0.109571
# nanx_state                       0.144962                0.055982
# nanx_trait                       0.153239                0.048025
# pcs_catastrophizing              0.024004               -0.023237
# pcs_rumination                  -0.262166               -0.308559
# PSQI                            -0.027921               -0.037023
# PSQ20                            0.028630                0.272167
# ads_k                            0.063446                0.025343
# Glx_mean                         0.001224               -0.198515
# GABA_mean                        0.045437               -0.096722
#
# connectivity         CER7b_m - PCcor.1  CER7b_l - R_PORB  CER6_d - OCCTgyr_l  \
# CPT                           0.269774         -0.010553           -0.202779
# nHPT                          0.167964         -0.120982           -0.027950
# nMPT                          0.219451         -0.343802           -0.197468
# nt50                          0.255984         -0.172967           -0.217371
# npsq                         -0.059947         -0.005772           -0.212751
# nanx_state                   -0.149586         -0.039920           -0.162293
# nanx_trait                   -0.143312         -0.083242           -0.165041
# pcs_catastrophizing           0.099360         -0.104100            0.065469
# pcs_rumination               -0.201499          0.027614           -0.259422
# PSQI                         -0.091958         -0.052302           -0.160002
# PSQ20                         0.307483         -0.098661           -0.129273
# ads_k                         0.026394          0.079938           -0.040126
# Glx_mean                      0.105756          0.026274           -0.010289
# GABA_mean                     0.238287          0.051947           -0.031950
#
# connectivity         CER6_d - MOTnet_m  ...  R_IPlob - STgyr_p  \
# CPT                          -0.193640  ...          -0.183506
# nHPT                         -0.172492  ...          -0.221293
# nMPT                         -0.327756  ...          -0.220520
# nt50                         -0.047768  ...          -0.167443
# npsq                         -0.274854  ...          -0.025163
# nanx_state                   -0.263870  ...          -0.008040
# nanx_trait                   -0.263757  ...           0.015895
# pcs_catastrophizing           0.050974  ...          -0.303288
# pcs_rumination               -0.202025  ...          -0.332272
# PSQI                         -0.209217  ...           0.132302
# PSQ20                        -0.283738  ...          -0.176648
# ads_k                        -0.086669  ...          -0.023842
# Glx_mean                     -0.271701  ...           0.125388
# GABA_mean                    -0.110073  ...          -0.189064
#
# connectivity         L_MFgyr_a - LORBgyr  CAUDNH_NACC - MOTnet_vl  \
# CPT                             0.305101                 0.069552
# nHPT                            0.153008                 0.137473
# nMPT                            0.169292                 0.233771
# nt50                            0.233145                 0.018380
# npsq                            0.035462                -0.180290
# nanx_state                      0.073469                -0.158115
# nanx_trait                      0.053506                -0.146116
# pcs_catastrophizing             0.001743                -0.098274
# pcs_rumination                 -0.193518                -0.050864
# PSQI                            0.157766                -0.046018
# PSQ20                           0.094205                 0.038987
# ads_k                           0.149938                -0.131829
# Glx_mean                        0.171461                -0.017245
# GABA_mean                      -0.025938                 0.387593
#
# connectivity         COLsul - MOTnet_vl  TP - CAUDN  MOTnet_m - LVISnet_p  \
# CPT                           -0.252543   -0.221531              0.174136
# nHPT                          -0.112379   -0.215045              0.298346
# nMPT                          -0.235179   -0.156909              0.439023
# nt50                          -0.464875   -0.315519              0.408920
# npsq                          -0.063695   -0.155950              0.282711
# nanx_state                    -0.016677   -0.118566              0.260548
# nanx_trait                    -0.010835   -0.145490              0.278432
# pcs_catastrophizing           -0.169969   -0.115292              0.032641
# pcs_rumination                -0.197305   -0.187242             -0.075319
# PSQI                          -0.006381    0.079150              0.352548
# PSQ20                         -0.200759   -0.118110              0.301214
# ads_k                         -0.011029    0.153293              0.118497
# Glx_mean                      -0.223773   -0.349253              0.389095
# GABA_mean                     -0.144002   -0.196398              0.511128
#
# connectivity         AINS_v - MVISnet_ad  STgyr_p - LVISnet_DP  \
# CPT                            -0.219074              0.066448
# nHPT                           -0.228620              0.283450
# nMPT                           -0.171467              0.092689
# nt50                           -0.324741             -0.082198
# npsq                           -0.083695              0.003573
# nanx_state                     -0.179421             -0.046450
# nanx_trait                     -0.172157             -0.013330
# pcs_catastrophizing             0.000470              0.087098
# pcs_rumination                 -0.249635             -0.046288
# PSQI                           -0.025996              0.013938
# PSQ20                          -0.203073             -0.046487
# ads_k                          -0.000716             -0.056921
# Glx_mean                       -0.114952              0.005965
# GABA_mean                      -0.169733             -0.057943
#
# connectivity         THAL_d - PCcor.1  THAL_v - PINS_d
# CPT                          0.176775         0.138239
# nHPT                         0.274513         0.187179
# nMPT                         0.348656         0.248983
# nt50                         0.286457         0.286114
# npsq                         0.051586        -0.010707
# nanx_state                   0.139687        -0.035873
# nanx_trait                   0.160756        -0.021476
# pcs_catastrophizing          0.010068        -0.000595
# pcs_rumination               0.109181         0.025208
# PSQI                         0.147407         0.015165
# PSQ20                        0.135216        -0.040917
# ads_k                       -0.031748         0.044036
# Glx_mean                    -0.199438        -0.015797
# GABA_mean                   -0.170070        -0.170313
#
# [14 rows x 39 columns]

# %%
sns.heatmap(corrmtx.T, cmap=sns.color_palette("vlag", as_cmap=True))
# Out:
# <AxesSubplot:ylabel='connectivity'>

# %%
norm = Normalize()
sns.clustermap(corrmtx.dropna(), cmap="vlag", figsize=(30,10), col_colors=cm.binary(norm(mc_model['abs_multi-center'])))

# %%
#Importing libraries
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram , linkage

# %%
#Linkage Matrix
Z = linkage(corrmtx.T, method = 'ward')
#plotting dendrogram
plt.figure(figsize=(20,10))
dendro = dendrogram(Z, labels=corrmtx.columns)
plt.title('Dendrogram')
plt.ylabel('Euclidean distance')
plt.xticks(fontsize = 12)
plt.show()

# %%
Z=pd.DataFrame(Z, index=corrmtx.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13746/513270312.py in <module>
# ----> 1 Z=pd.DataFrame(Z, index=corrmtx.columns)
#
# ~/src/RPN-signature/venv/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~/src/RPN-signature/venv/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~/src/RPN-signature/venv/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (38, 4), indices imply (39, 4)

# %%
corrmtx.shape

# %%
Z
